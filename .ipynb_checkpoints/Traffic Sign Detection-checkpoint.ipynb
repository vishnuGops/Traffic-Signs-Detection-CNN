# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
imgs_path = "input\Train"
data_list = []
labels_list = []
classes_list = 43
for i in range(classes_list):
    i_path = os.path.join(imgs_path, str(i)) #0-42
    for img in os.listdir(i_path):
        im = Image.open(i_path +'/'+ img)
        im = im.resize((32,32))
        im = np.array(im)
        data_list.append(im)
        labels_list.append(i)
data = np.array(data_list)
labels = np.array(labels_list)

# %%
plt.figure(figsize = (12,12))

for i in range(4) :
    plt.subplot(1, 4, i+1)
    plt.imshow(data[i], cmap='gray')

plt.show()

# %%
def prep_dataset(X,y):
    X_prep = X.astype('float32')
    y_prep = to_categorical(np.array(y))
    return (X_prep, y_prep)

X, y = prep_dataset(data,labels)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X,y, test_size=0.8, shuffle=True,stratify=y)
X_val, X_test, Y_val, Y_test = train_test_split(X_val,Y_val, test_size=0.5, shuffle=True)

# %%
model = models.Sequential() #Sequential Model

#ConvLayer(64 filters) + MaxPooling + BatchNormalization + Dropout
model.add(layers.Conv2D(filters=32,kernel_size=3,activation='relu',padding='same',input_shape=X.shape[1:]))
model.add(layers.MaxPool2D(strides=2))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.3))

#ConvLayer(128 filters) + MaxPooling + BatchNormalization + Dropout
model.add(layers.Conv2D(filters=128,kernel_size=3,activation='relu',padding='same'))
model.add(layers.MaxPool2D(strides=2))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.3))

#ConvLayer(512 filters) + Dropout + ConvLayer(512 filters) + MaxPooling + BatchNormalization
model.add(layers.Conv2D(filters=512,kernel_size=3,activation='relu',padding='same'))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(filters=512,kernel_size=3,activation='relu',padding='same'))
model.add(layers.MaxPool2D(strides=2))
model.add(layers.BatchNormalization())

#Flatten
model.add(layers.Flatten())

#2 Dense layers with 4000 hidden units
model.add(layers.Dense(4000,activation='relu'))
model.add(layers.Dense(4000,activation='relu'))

#Dense layer with 1000 hidden units
model.add(layers.Dense(1000,activation='relu'))

#Softmax layer for output
model.add(layers.Dense(43,activation='softmax'))

# %%
model.compile(optimizer='adam',
            loss='categorical_crossentropy',
            metrics=['accuracy'])

history= model.fit(X_train,Y_train,
                epochs=20,
                batch_size=64,
                validation_data=(X_val,Y_val))
# Out:
# Epoch 1/20
# 123/123 [==============================] - 9s 35ms/step - loss: 3.2343 - accuracy: 0.2037 - val_loss: 2.0260 - val_accuracy: 0.3648
# Epoch 2/20
# 123/123 [==============================] - 4s 29ms/step - loss: 1.5644 - accuracy: 0.4817 - val_loss: 1.2554 - val_accuracy: 0.5632
# Epoch 3/20
# 123/123 [==============================] - 3s 28ms/step - loss: 0.8939 - accuracy: 0.6965 - val_loss: 0.5797 - val_accuracy: 0.8135
# Epoch 4/20
# 123/123 [==============================] - 3s 28ms/step - loss: 0.4755 - accuracy: 0.8449 - val_loss: 0.4393 - val_accuracy: 0.8555
# Epoch 5/20
# 123/123 [==============================] - 4s 29ms/step - loss: 0.2807 - accuracy: 0.9073 - val_loss: 0.2498 - val_accuracy: 0.9185
# Epoch 6/20
# 123/123 [==============================] - 3s 28ms/step - loss: 0.2030 - accuracy: 0.9325 - val_loss: 0.2399 - val_accuracy: 0.9378
# Epoch 7/20
# 123/123 [==============================] - 4s 30ms/step - loss: 0.1411 - accuracy: 0.9528 - val_loss: 0.1698 - val_accuracy: 0.9517
# Epoch 8/20
# 123/123 [==============================] - 4s 30ms/step - loss: 0.1243 - accuracy: 0.9617 - val_loss: 0.1202 - val_accuracy: 0.9649
# Epoch 9/20
# 123/123 [==============================] - 4s 30ms/step - loss: 0.0992 - accuracy: 0.9699 - val_loss: 0.1424 - val_accuracy: 0.9607
# Epoch 10/20
# 123/123 [==============================] - 4s 30ms/step - loss: 0.0891 - accuracy: 0.9704 - val_loss: 0.1118 - val_accuracy: 0.9707
# Epoch 11/20
# 123/123 [==============================] - 4s 30ms/step - loss: 0.1052 - accuracy: 0.9676 - val_loss: 0.1238 - val_accuracy: 0.9654
# Epoch 12/20
# 123/123 [==============================] - 4s 30ms/step - loss: 0.0806 - accuracy: 0.9756 - val_loss: 0.2000 - val_accuracy: 0.9571
# Epoch 13/20
# 123/123 [==============================] - 3s 27ms/step - loss: 0.1110 - accuracy: 0.9698 - val_loss: 0.1924 - val_accuracy: 0.9531
# Epoch 14/20
# 123/123 [==============================] - 4s 29ms/step - loss: 0.0903 - accuracy: 0.9725 - val_loss: 0.1107 - val_accuracy: 0.9730
# Epoch 15/20
# 123/123 [==============================] - 3s 27ms/step - loss: 0.0831 - accuracy: 0.9754 - val_loss: 0.1563 - val_accuracy: 0.9587
# Epoch 16/20
# 123/123 [==============================] - 3s 28ms/step - loss: 0.0792 - accuracy: 0.9810 - val_loss: 0.0855 - val_accuracy: 0.9790
# Epoch 17/20
# 123/123 [==============================] - 3s 28ms/step - loss: 0.0674 - accuracy: 0.9793 - val_loss: 0.0996 - val_accuracy: 0.9740
# Epoch 18/20
# 123/123 [==============================] - 3s 27ms/step - loss: 0.0729 - accuracy: 0.9815 - val_loss: 0.1643 - val_accuracy: 0.9624
# Epoch 19/20
# 123/123 [==============================] - 3s 28ms/step - loss: 0.0727 - accuracy: 0.9828 - val_loss: 0.1338 - val_accuracy: 0.9676
# Epoch 20/20
# 123/123 [==============================] - 4s 29ms/step - loss: 0.0748 - accuracy: 0.9800 - val_loss: 0.1181 - val_accuracy: 0.9685

# %%
fig, ax=plt.subplots(2,1,figsize=(12,10))
fig.suptitle('Train evaluation')

sns.lineplot(ax= ax[0],x=np.arange(0,len(history.history['accuracy'])),y=history.history['accuracy'])
sns.lineplot(ax= ax[0],x=np.arange(0,len(history.history['accuracy'])),y=history.history['val_accuracy'])

ax[0].legend(['Train','Validation'])
ax[0].set_title('Accuracy')

sns.lineplot(ax= ax[1],x=np.arange(0,len(history.history['loss'])),y=history.history['loss'])
sns.lineplot(ax= ax[1],x=np.arange(0,len(history.history['loss'])),y=history.history['val_loss'])

ax[1].legend(['Train','Validation'])
ax[1].set_title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
Y_test = np.argmax(Y_test,axis=1)

Y_pred= model.predict(X_test)

Y_pred = np.argmax(Y_pred, axis=1)

print('-Acuracy achieved: {:.2f}%\n-Accuracy by model was: {:.2f}%\n-Accuracy by validation was: {:.2f}%'.
      format(accuracy_score(Y_test,Y_pred)*100,(history.history['accuracy'][-1])*100,(history.history['val_accuracy'][-1])*100))
# Out:
# 491/491 [==============================] - 2s 3ms/step
# -Acuracy achieved: 97.30%
# -Accuracy by model was: 98.00%
# -Accuracy by validation was: 96.85%
